# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("fedesoriano/heart-failure-prediction")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'heart-failure-prediction' dataset.
# Path to dataset files: /kaggle/input/heart-failure-prediction

# %%
# !git config --global user.name "Blazejost"
# !git config --global user.email "blazejostaszewski@gmail.com"

# %%
# !git clone https://github.com/Blazejost/Heart-Failure-Prediction-Project.git
# %cd Heart-Failure-Prediction-Project
# Out:
# Cloning into 'Heart-Failure-Prediction-Project'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 12 (delta 3), reused 8 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), done.
# Resolving deltas: 100% (3/3), done.
# /content/Heart-Failure-Prediction-Project

# %%
# !cp /content/heart_failure_notebook.ipynb .
# Out:
# cp: cannot stat '/content/heart_failure_notebook.ipynb': No such file or directory

# %%
# !cp /content/heart_failure.ipynb .
# Out:
# cp: cannot stat '/content/heart_failure.ipynb': No such file or directory

# %%
# !cp /content/exploratory_data_analysis/heart_failure.ipynb .
# Out:
# cp: cannot stat '/content/exploratory_data_analysis/heart_failure.ipynb': No such file or directory

# %%
# !cp /exploratory_data_analysis/heart_failure.ipynb .
# Out:
# cp: cannot stat '/exploratory_data_analysis/heart_failure.ipynb': No such file or directory

# %%
# !git clone https://{Blazejost}:{Golego2004#}@github.com/{Heart-Failure-Prediction-Project}/{Heart-Failure-Prediction-Project}.git
# Out:
# Cloning into '{Heart-Failure-Prediction-Project}'...
# fatal: unable to access 'https://github.com/{Heart-Failure-Prediction-Project}/{Heart-Failure-Prediction-Project}.git/': URL using bad/illegal format or missing URL

# %%
# !git clone https://{Blazejost}:{Golego2004#}@github.com/Blazejost/Heart-Failure-Prediction-Project.git
# Out:
# Cloning into 'Heart-Failure-Prediction-Project'...
# fatal: unable to access 'https://github.com/Blazejost/Heart-Failure-Prediction-Project.git/': URL using bad/illegal format or missing URL

# %%
# !git clone https://github.com/Blazejost/Heart-Failure-Prediction-Project.git
# Out:
# Cloning into 'Heart-Failure-Prediction-Project'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 12 (delta 3), reused 8 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), done.
# Resolving deltas: 100% (3/3), done.
